# %% [markdown]
# <a href="https://colab.research.google.com/github/Developers-07/Python/blob/main/LabTask_05(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/weather.numeric.csv")
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny         85.0      85.0  False   no
# 1      sunny         80.0       NaN   True   no
# 2   overcast         83.0       NaN  False  yes
# 3      rainy         70.0      96.0  False  yes
# 4      rainy          NaN      80.0  False  yes
# 5      rainy         65.0      70.0   True   no
# 6   overcast         64.0      65.0   True  yes
# 7      sunny         72.0       NaN  False   no
# 8      sunny          NaN      70.0    NaN  NaN
# 9      rainy         75.0      80.0    NaN  NaN
# 10     sunny         75.0      70.0    NaN  NaN
# 11  overcast         72.0      90.0   True  yes
# 12  overcast         81.0       NaN  False  yes
# 13     rainy         71.0      91.0   True   no

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
df.isnull().sum()
# Out:
# outlook        0
# temperature    2
# humidity       4
# windy          3
# play           3
# dtype: int64

# %%
df.dtypes
# Out:
# outlook         object
# temperature    float64
# humidity       float64
# windy           object
# play            object
# dtype: object

# %% [markdown]
# ## **Missing Handling**

# %%
df["temperature"].fillna(1001,inplace=True)
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny         85.0      85.0  False   no
# 1      sunny         80.0      79.7   True   no
# 2   overcast         83.0      79.7  False  yes
# 3      rainy         70.0      96.0  False  yes
# 4      rainy       1001.0      80.0  False  yes
# 5      rainy         65.0      70.0   True   no
# 6   overcast         64.0      65.0   True  yes
# 7      sunny         72.0      79.7  False   no
# 8      sunny       1001.0      70.0    NaN  NaN
# 9      rainy         75.0      80.0    NaN  NaN
# 10     sunny         75.0      70.0    NaN  NaN
# 11  overcast         72.0      90.0   True  yes
# 12  overcast         81.0      79.7  False  yes
# 13     rainy         71.0      91.0   True   no

# %%
df["humidity"].mean()
# Out:
# 79.7

# %%
df["humidity"].fillna(79.7,inplace=True)
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny         85.0      85.0  False   no
# 1      sunny         80.0      79.7   True   no
# 2   overcast         83.0      79.7  False  yes
# 3      rainy         70.0      96.0  False  yes
# 4      rainy       1001.0      80.0  False  yes
# 5      rainy         65.0      70.0   True   no
# 6   overcast         64.0      65.0   True  yes
# 7      sunny         72.0      79.7  False   no
# 8      sunny       1001.0      70.0    NaN  NaN
# 9      rainy         75.0      80.0    NaN  NaN
# 10     sunny         75.0      70.0    NaN  NaN
# 11  overcast         72.0      90.0   True  yes
# 12  overcast         81.0      79.7  False  yes
# 13     rainy         71.0      91.0   True   no

# %%
df["windy"].value_counts()
# Out:
# False    6
# True     5
# Name: windy, dtype: int64

# %%
df["windy"].fillna("False",inplace=True)
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny         85.0      85.0  False   no
# 1      sunny         80.0      79.7   True   no
# 2   overcast         83.0      79.7  False  yes
# 3      rainy         70.0      96.0  False  yes
# 4      rainy       1001.0      80.0  False  yes
# 5      rainy         65.0      70.0   True   no
# 6   overcast         64.0      65.0   True  yes
# 7      sunny         72.0      79.7  False   no
# 8      sunny       1001.0      70.0  False  NaN
# 9      rainy         75.0      80.0  False  NaN
# 10     sunny         75.0      70.0  False  NaN
# 11  overcast         72.0      90.0   True  yes
# 12  overcast         81.0      79.7  False  yes
# 13     rainy         71.0      91.0   True   no

# %%
df["play"].value_counts()
# Out:
# yes    6
# no     5
# Name: play, dtype: int64

# %%
df["play"].fillna("yes",inplace=True)
df
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny         85.0      85.0  False   no
# 1      sunny         80.0      79.7   True   no
# 2   overcast         83.0      79.7  False  yes
# 3      rainy         70.0      96.0  False  yes
# 4      rainy       1001.0      80.0  False  yes
# 5      rainy         65.0      70.0   True   no
# 6   overcast         64.0      65.0   True  yes
# 7      sunny         72.0      79.7  False   no
# 8      sunny       1001.0      70.0  False  yes
# 9      rainy         75.0      80.0  False  yes
# 10     sunny         75.0      70.0  False  yes
# 11  overcast         72.0      90.0   True  yes
# 12  overcast         81.0      79.7  False  yes
# 13     rainy         71.0      91.0   True   no

# %% [markdown]
# ## **Feature Selection Technique**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b94e0414-53a8-4217-b4cb-033590f3ab6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b94e0414-53a8-4217-b4cb-033590f3ab6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
dff=pd.read_csv("heart.csv")
dff
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
x=dff.drop("target",axis=1)
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y=dff["target"]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model=ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
fs=pd.DataFrame(model.feature_importances_,index=x.columns, columns=["score values"])
fs
# Out:
#           score values
# age           0.070672
# sex           0.056219
# cp            0.127674
# trestbps      0.057027
# chol          0.056146
# fbs           0.019770
# restecg       0.037697
# thalach       0.088643
# exang         0.107239
# oldpeak       0.092249
# slope         0.063737
# ca            0.125160
# thal          0.097767

# %%
fs.nlargest(13,"score values")
# Out:
#           score values
# cp            0.127674
# ca            0.125160
# exang         0.107239
# thal          0.097767
# oldpeak       0.092249
# thalach       0.088643
# age           0.070672
# slope         0.063737
# trestbps      0.057027
# sex           0.056219
# chol          0.056146
# restecg       0.037697
# fbs           0.019770
